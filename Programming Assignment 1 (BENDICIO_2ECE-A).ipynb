# %% [markdown]
# # SEDRIC LANCE B. BENDICIO

# %% [markdown]
# ## 2ECE-A

# %% [markdown]
# ### A. WORD ROTATION PROBLEM

# %%
def rotate_word(text):
    return text[1:len(text):1]+text[0:1]

# %%
rotate_word("python")
# Out:
# 'ythonp'

# %%
rotate_word("logic")
# Out:
# 'ogicl'

# %%
rotate_word("Code")
# Out:
# 'odeC'

# %%
rotate_word("A")
# Out:
# 'A'

# %% [markdown]
# ### B. USERNAME BUILDER PROBLEM

# %%
def make_username(first_name, last_name):
    return first_name.lower().replace(" ", "")+"."+last_name.lower().replace(" ", "")

# %%
make_username("Ada", "Lovelace")
# Out:
# 'ada.lovelace'

# %%
make_username("Alan", "Turing")
# Out:
# 'alan.turing'

# %%
make_username("Ana Maria", "De Leon")
# Out:
# 'anamaria.deleon'

# %% [markdown]
# ### C. BOOKEND SWAP PROBLEM

# %%
def swap_bookends(items):
    first, *middle, last = items
    return print(last, *middle, first)

# %%
swap_bookends([1, 2, 3, 4, 5, 6])
# Out:
# 6 2 3 4 5 1

# %%
swap_bookends(["red", "green", "blue"])
# Out:
# blue green red

# %%
swap_bookends([8, 3])
# Out:
# 3 8
